# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import vaex as vx
import bar_chart_race as bcr
import zipfile

# %%
with zipfile.ZipFile('Datasets/494766_1289348_bundle_archive.zip') as z:
    print(z.namelist(), sep='/n')
# Out:
# ['country_wise_latest.csv', 'covid_19_clean_complete.csv', 'day_wise.csv', 'full_grouped.csv', 'usa_county_wise.csv', 'worldometer_data.csv']

# %%
with zipfile.ZipFile('Datasets/494766_1289348_bundle_archive.zip') as z:
    with z.open('covid_19_clean_complete.csv') as f:
        data = vx.read_csv(f)

# %%
data.head()
# Out:
#   #  Province/State                Country/Region            Lat      Long  Date          Confirmed    Deaths    Recovered    Active  WHO Region
#   0  nan                           Afghanistan           33        65       2020-01-22            0         0            0         0  Eastern Mediterranean
#   1  nan                           Albania               41.1533   20.1683  2020-01-22            0         0            0         0  Europe
#   2  nan                           Algeria               28.0339    1.6596  2020-01-22            0         0            0         0  Africa
#   3  nan                           Andorra               42.5063    1.5218  2020-01-22            0         0            0         0  Europe
#   4  nan                           Angola               -11.2027   17.8739  2020-01-22            0         0            0         0  Africa
# ...

# %%
data = data.to_pandas_df()

# %%
datan = pd.DataFrame(data.groupby(['WHO Region','Date']).sum()['Confirmed']).unstack().T.droplevel(level=0)

# %%
datan.head()
# Out:
# WHO Region  Africa  Americas  Eastern Mediterranean  Europe  South-East Asia  \
# Date
# 2020-01-22       0         1                      0       0                2
# 2020-01-23       0         1                      0       0                3
# 2020-01-24       0         2                      0       2                5
# 2020-01-25       0         2                      0       3                8
# 2020-01-26       0         6                      0       3                9
#
# WHO Region  Western Pacific
# Date
# 2020-01-22              552
# 2020-01-23              650
# 2020-01-24              932
# 2020-01-25             1421
# 2020-01-26             2100

# %%
bcr.bar_chart_race(datan)
# Out:
# INFO:MainThread:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:MainThread:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:MainThread:matplotlib.animation:figure size (inches) has been adjusted from 7.036458333333333 x 3.5 to 7.027777777777778 x 3.5
# INFO:MainThread:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '1012x504', '-pix_fmt', 'rgba', '-r', '20.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', 'C:\\Users\\FAMILI~1\\AppData\\Local\\Temp\\tmpq7q7cq3x\\temp.m4v']
# <video width="1012" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
