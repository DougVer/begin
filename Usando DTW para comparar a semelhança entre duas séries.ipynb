# %%
#Usando os resultados do notebook 'prev titanic' para comparação das semelhanças
#entre os valores reais e os valores previstos


import numpy as np

# Definindo as sequencias a serem comparadas em array
x = fram['Survived'].values
y = pred

from dtw import dtw

manhattan_distance = lambda x, y: np.abs(x - y)

d, cost_matrix, acc_cost_matrix, path = dtw(x, y, dist=manhattan_distance)

print('ExtraTreesClassifier')
print(d)

# Visualizando a comparação através do matplotlib
import matplotlib.pyplot as plt

plt.imshow(acc_cost_matrix.T, origin='lower', cmap='gray', interpolation='nearest')
plt.plot(path[0], path[1], 'w')
plt.show()
# Out:
# ExtraTreesClassifier
# 16.0

# %%
import numpy as np

# Definindo as sequencias a serem comparadas em array
x = fram['Survived'].values
y = pred2

from dtw import dtw

manhattan_distance = lambda x, y: np.abs(x - y)

d, cost_matrix, acc_cost_matrix, path = dtw(x, y, dist=manhattan_distance)

print('KNeighborsClassifier')
print(d)

# Visualizando a comparação através do matplotlib
import matplotlib.pyplot as plt

plt.imshow(acc_cost_matrix.T, origin='lower', cmap='gray', interpolation='nearest')
plt.plot(path[0], path[1], 'w')
plt.show()
# Out:
# KNeighborsClassifier
# 14.0

# %%
import numpy as np

# Definindo as sequencias a serem comparadas em array
x = fram['Survived'].values
y = pred3

from dtw import dtw

manhattan_distance = lambda x, y: np.abs(x - y)

d, cost_matrix, acc_cost_matrix, path = dtw(x, y, dist=manhattan_distance)

print('GaussianNB')
print(d)

# Visualizando a comparação através do matplotlib
import matplotlib.pyplot as plt

plt.imshow(acc_cost_matrix.T, origin='lower', cmap='gray', interpolation='nearest')
plt.plot(path[0], path[1], 'w')
plt.show()
# Out:
# GaussianNB
# 3.0
